# %% [markdown]
# # Assignment

# %%
# Translate the following RNA sequence to its one-letter amino acid (protein) code: LADSRQSKTA
rna_seq = "uuggcagauu cccgccagag caaaacagcc"

# %%
translation_table = {"UUG": "L_Leu", 
                     "GCA": "A_Ala", 
                     "GAU": "D_Asp",
                     "UCC": "S_Ser",
                     "CGC": "R_Arg",
                     "CAG": "Q_Gln",
                     "AGC": "S_Ser",
                     "AAA": "K_Lys",
                     "ACA": "T_Thr", 
                     "GCC": "A_Ala"}

# %% [markdown]
# ## Hints

# %% [markdown]
# 1. Review the `.split()`, `.join()`, and `.upper()` methods for manipulating strings.
# 2. Review how to index and slice strings. Remember that Python starts counting from 0.
# 3. Review how to use Python dictionaries. You can access the values in a dictionary if you know the key, like this:

# %%
print(translation_table["UUG"])
# Out:
# L_Leu

# %% [markdown]
# 4. `for` loops are helpful! You can find out all the dictionary keys with a `for` loop like this:

# %%
for key in translation_table.keys():
    print(key)
# Out:
# UUG
# GCA
# GAU
# UCC
# CGC
# CAG
# AGC
# AAA
# ACA
# GCC

# %% [markdown]
# 5. Additional helpful functions: The built-in Python [`range()`](https://docs.python.org/2/library/functions.html#range) function can take three arguments: start number, end number, and step size. For example:

# %%
for positions in range(0, 27, 3):
    print(positions)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
