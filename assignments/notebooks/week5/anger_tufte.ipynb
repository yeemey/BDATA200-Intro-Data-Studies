# %% [markdown]
# # Exercise: The Wrath of Tufte
#
#  We have in other sections discussed some principles of data communication, emphasizing some of the principles in Edward Tufte's *The Visual Display of Quantitative Information*. In this Exercise, we will implement some code to simulate how sampling depth (i.e. the number of DNA sequences collected per sample) influences the observed alpha diversity of a microbiome. Then we will create a graph of this data that violates as many of Tufte's principles simultaneously. Here's a sneak peak of three graphs:
#
# <img src="resources/rarefaction_1000.png" alt="An explosion of garish color. Squinting, a viewer may see a line graph with sequencing depth on the x-axis and observed species richness on the y-axis. But the graph is a mess — random sized x and y axis fonts; heavy yellow gridlines overlayed over the whole thing; the area between the line and the x-axis filled in with black and red stars on a deep purble background; a thick yellow dot dashed line for the line plot, etc" width="400">
#
#
# Your goal will be to revise this graph into something more sensible. If you like, you can skip directly to the graphing code in the make_rarefaction_graph function. *Hint*: simply deleting some of the code and parameters that make the graph so horrible will get you at least part of the way there.

# %%
# Importing libraries and functions we'll need

# %matplotlib inline
from random import choice
from collections import defaultdict
import matplotlib.pyplot as plt
from math import log
# Out:
# Bad key text.latex.preview in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 123 ('text.latex.preview : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key mathtext.fallback_to_cm in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 155 ('mathtext.fallback_to_cm : True  # When True, use symbols from the Computer Modern')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key savefig.jpeg_quality in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 418 ('savefig.jpeg_quality: 95       # when a jpeg is saved, the default quality parameter.')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key verbose.level in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key keymap.all_axes in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 490 ('keymap.all_axes : a                 # enable all axes')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key animation.avconv_path in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 501 ('animation.avconv_path: avconv     # Path to avconv binary. Without full path')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key animation.avconv_args in file /Users/yeemayseah/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle, line 503 ('animation.avconv_args:            # Additional arguments to pass to avconv')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.7.5/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %% [markdown]
# ## Set up the input data for the graph
#
#  The goal of our graph is to convey how different sampling depths change the perceived complexity or richness of a microbial community. To do that, we must first represent the whole community (i.e. the biological truth), and then simulate the effect of drawing random samples of various sizes from that community (i.e. observations that approximate what's in the full community with varying degrees of error).
#
#  #### Define a function to simulate a 'true' microbiome
#  First let's define a function to generate the 'true' microbiome in our simulation. We'll want our microbiome — like many real microbial communities — to have members with varying abundances. A few may be quite common, but many diverse microbes will be very rare.

# %%
def make_microbiome(total=10000000,common=0.70,uncommon=0.25,rare=0.04,very_rare=0.004,\
    uber_rare=0.0004,most_rare=0.00001):
    """Return a simulated microbiome as a list of species
    NOTE: this is just a simple demo real simulations would use a 
    specific distribution of rare vs. abundant species
    
    """
    microbiome = ['species1']*int(common*total)+\
      ['species2']*int(uncommon*total)+\
      ['species3']*int(rare*total)+\
      ['species4']*int(very_rare*total)+\
      ['species5']*int(very_rare*total)+\
      ['species6']*int(uber_rare*total)+\
      ['species7']*int(uber_rare*total)+\
      ['species8']*int(uber_rare*total)+\
      ['species9']*int(uber_rare*total)+\
      ['species10']*int(uber_rare*total)+\
      ['species11']*int(most_rare*total)
    
    return microbiome

# %% [markdown]
# #### Define a function to sample from the 'true' microbiome to produce observations
#
# In biology, we almost never get to enumerate an entire microbial community. Instead, we have observations that represent samples from the true biological population. We can simulate that process in python by using the choice function to repeatedly draw a certain number of microbes from the true community that we simulated. This represents what DNA sequences we might see if doing a marker gene study with a particular sampling depth on the true community.

# %%
def sample_microbiome(microbiome,depth):
    """Return a dict of species:count by selection species at random from a list of species
    microbiome -- a list of strings representing species 
      example: ['species1','species1','species1','species2', etc]
    depth -- depth to sample as int
    """
    counts = defaultdict(int)
    for i in range(depth):
        read = (choice(microbiome)) 
        counts[read] += 1
    return counts

# %% [markdown]
# #### Define a function to count observed species from a dict
#
# Our sample function returns a `dict` object that connects each species (the keys of our `dict`) to the number of times that species was observed (the values of the `dict`).
#
# The length of a dictionary is the same as the number of items in the dict, so calling `len` on the counts dict will get us the number of observed species:

# %%
def obs_species(counts):
    """Returns the number of observed species
    counts -- defaultdict of species counts"""
    return(len(counts))

# %% [markdown]
# ## Graph the Data
#
# Now we need to graph the observed species richness of our sample at varying levels of sequencing depth. This particular graphing code has horrible, no-good, very bad styling — styling that will attract The Wrath of Tufte. Hopefully, you will hopefully be able to adjust this graph to make it better.

# %%
def rarefaction_graph(x,y,outfile="rarefaction.png",fontsize=16,font="Arial"):
    """Graph species vs. sampling effort
    x -- a list of x values
    y -- a list of y values
    outfile -- path to save the graph.  Note that the .png extension is important, as matplotlib 
    guesses output filetype based on suffix

    Hat tip to Stack Overflow on an elegant stategy for adjusting font sizes: 
    http://stackoverflow.com/questions/3899980/how-to-change-the-font-size-on-a-matplotlib-plot
    """
    ax =plt.subplot()
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontname(font)
        #Randomly adjust the label size 
        label.set_fontsize(fontsize + choice(([5,2,1,-1,-2,-5]))) 

    # Set the font dictionaries (for plot title and axis titles)
    title_font = {'fontname':'Arial', 'size':'16', 'color':'black', 'weight':'normal',
              'verticalalignment':'bottom'} 
    
    #It would be boring to have the x and y axis in the same font
    x_axis_font = {'fontname':'Arial', 'size':'8'}
    y_axis_font = {'fontname':'Times New Roman', 'size':'22'}
    
    #Plot the results with a nice thick yellow dot-dashed line
    plt.plot(x,y,c='yellow',linestyle='-.',linewidth=3.0)
    
    #Add heavy black and yellow gridlines
    plt.grid(True, which='major', color='y', linestyle='-',linewidth=4.0)
    
    #Turn on minor ticks so you can see our minor gridlines
    plt.minorticks_on()
    
    #Now make some beautfiful thick minor gridlines
    plt.grid(True, which='minor', color='pink', linestyle='-',linewidth=2.0)
 
    #No need to set consistent y-axis limits
    #so graphs can be compared - readers will figure it out
    
    #ax.set_ylim([0,12])

    #Fill the area between the line and the x-axis with a star pattern
    ax.fill_between(x,y, hatch='*',facecolor='r',edgecolor='none')
    
    #Change two axes to be colorful
    ax.spines['top'].set_color('pink') 
    ax.spines['right'].set_color('blue')
    
    #Set the background color
    ax.set_facecolor('purple')
    
    #Show ticks just on bottom left
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    #Set unique font styles for x and y axis
    plt.ylabel('Observed OTUs',**y_axis_font)
    plt.xlabel('Sampling Depth',**x_axis_font)
    plt.savefig(outfile)
    plt.show()

if __name__ == "__main__":
    #This script simulates sampling from microbiomes of various
    #depths, then makes horrible graphs representing them.
    #Your task is to fix the rarefaction_graph function so that 
    #the graphs are less awful.

    #Generate a list of strings representing a microbiome
    microbiome = make_microbiome(total=1000000)
    
    
    graph_depths = [50,500,1000,50]
    sampling_depths = range(10,1010,10)
    x = []
    y = []
    iterations = 5
    for sampling_depth in sampling_depths: 
        curr_counts = []
        for i in range(iterations):
            microbiome_sample = sample_microbiome(microbiome,sampling_depth)
            curr_count = obs_species(microbiome_sample)
            curr_counts.append(curr_count)
        counts = sum(curr_counts)/len(curr_counts)
        x.append(sampling_depth)
        y.append(counts)
        if sampling_depth in graph_depths:
            rarefaction_graph(x,y,outfile="rarefaction_%i"%sampling_depth)
            print("Outputing chart: rarefaction_%i"%sampling_depth)
# Out:
# Outputing chart: rarefaction_50
# Outputing chart: rarefaction_500
# Outputing chart: rarefaction_1000

# %% [markdown]
# ## Troubleshooting
#
# - If you get a `ValueError: keyword grid_b is not recognized` when using `plt.grid(b=True)`, check the version of matplotlib, and use `plt.grid(True)` instead.
# - If you get `findfont: Font family 'Arial' not found` or `findfont: Font family 'Times New Roman' not found`, check what fonts are available and use those instead.

# %%
# Check matplotlib version.
# Note: your version of matplotlib may be different than what's shown here
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.5

# %%
# Check available font types
# Note: your available fonts may be different than what's shown here
from matplotlib import font_manager
for font in font_manager.fontManager.ttflist:
    print(font.name)
# Out:
# DejaVu Sans
# DejaVu Sans Mono
# STIXSizeThreeSym
# STIXGeneral
# cmss10
# STIXGeneral
# DejaVu Serif
# cmr10
# DejaVu Sans Display
# STIXSizeOneSym
# cmex10
# cmsy10
# DejaVu Serif
# STIXSizeFourSym
# DejaVu Serif
# STIXSizeOneSym
# DejaVu Serif
# DejaVu Sans Mono
# STIXNonUnicode
# STIXSizeThreeSym
# STIXNonUnicode
# DejaVu Sans
# STIXSizeFourSym
# STIXNonUnicode
# cmb10
# cmmi10
# DejaVu Sans
# DejaVu Serif Display
# STIXGeneral
# cmtt10
# STIXSizeTwoSym
# STIXNonUnicode
# DejaVu Sans Mono
# STIXSizeFiveSym
# DejaVu Sans
# STIXSizeTwoSym
# STIXGeneral
# DejaVu Sans Mono
# Bodoni Ornaments
# Athelas
# .SF Compact Text
# Lahore Gurmukhi
# Kai
# Devanagari Sangam MN
# Georgia
# Yuppy SC
# Arial Narrow
# Helvetica Neue
# STIXIntegralsD
# .SF NS Display Condensed
# Weibei SC
# ITF Devanagari
# STIXIntegralsD
# Damascus
# Luminari
# Helvetica
# Courier New
# Symbol
# Hiragino Sans
# Noto Sans Cuneiform
# Wawati TC
# Trebuchet MS
# Heiti TC
# STIXIntegralsUpD
# Apple Chancery
# Apple LiGothic
# Noto Sans Saurashtra
# .Arabic UI Display
# Noto Sans Cham
# Noto Nastaliq Urdu
# Noto Sans Gothic
# Courier New
# Kailasa
# STIXIntegralsSm
# Baloo Tammudu
# Noto Sans Myanmar
# Marker Felt
# Khmer Sangam MN
# Sana
# Noto Sans Syriac
# Hiragino Mincho ProN
# Al Nile
# Hiragino Sans
# Times New Roman
# Toppan Bunkyu Midashi Gothic
# BiauKai
# PT Serif Caption
# Noto Sans Ogham
# Raanana
# STHeiti
# Bodoni 72
# LingWai SC
# .SF NS Text Condensed
# .Helvetica Neue DeskInterface
# HeadLineA
# .SF NS Text Condensed
# Apple Braille
# Sukhumvit Set
# Gujarati Sangam MN
# Muna
# STIXIntegralsSm
# Al Bayan
# LiSong Pro
# STIXSizeTwoSym
# Maku
# Toppan Bunkyu Midashi Mincho
# YuGothic
# Mukta Malar
# Sathu
# STFangsong
# Noto Sans Carian
# AppleGothic
# Noto Sans Kayah Li
# Zapf Dingbats
# Noto Sans Lydian
# Baghdad
# Nanum Brush Script
# Mishafi Gold
# Thonburi
# Noto Sans New Tai Lue
# Noto Sans Imperial Aramaic
# Silom
# STIXVariants
# STIXIntegralsUp
# Noto Sans Brahmi
# Trebuchet MS
# Hei
# .New York
# Galvji
# Tamil MN
# Farah
# Arial
# Sinhala MN
# Diwan Kufi
# STIXSizeThreeSym
# Hiragino Sans GB
# Noto Sans Mongolian
# Rockwell
# InaiMathi
# STIXSizeThreeSym
# Lao Sangam MN
# Libian SC
# Hiragino Sans
# PilGi
# Noto Sans Old South Arabian
# Xingkai SC
# Gurmukhi MN
# Papyrus
# Noto Serif Myanmar
# Tiro Telugu
# Geeza Pro
# Baloo Bhaijaan
# Noto Sans Mandaic
# Mshtakan
# .SF NS Display Condensed
# .SF NS Rounded
# Plantagenet Cherokee
# Telugu MN
# Apple Symbols
# Songti SC
# Phosphate
# Arial Narrow
# Baloo Tamma
# AppleMyungjo
# Georgia
# Noto Sans Chakma
# Yuppy TC
# STIXSizeOneSym
# Times
# .Arabic UI Text
# Noto Sans Lepcha
# Noto Sans Ugaritic
# Herculanum
# Baloo Bhai
# Apple SD Gothic Neo
# Bangla Sangam MN
# Andale Mono
# Yuanti SC
# Tiro Gurmukhi
# Noto Sans Glagolitic
# Tiro Tamil
# .SF NS Display Condensed
# Telugu Sangam MN
# Al Tarikh
# Charter
# Hiragino Sans
# .SF NS Display Condensed
# Hiragino Maru Gothic Pro
# Kannada Sangam MN
# STIXIntegralsUpSm
# Malayalam MN
# STIXSizeFourSym
# Tsukushi B Round Gothic
# Gurmukhi Sangam MN
# Noto Sans Egyptian Hieroglyphs
# System Font
# Kohinoor Telugu
# Noto Sans Tai Tham
# Noto Sans Osmanya
# Shobhika
# Noto Sans Old Italic
# STIXNonUnicode
# STIXNonUnicode
# Modak
# Noto Sans Thaana
# Noto Sans Armenian
# Osaka
# Georgia
# Noto Sans Cypriot
# Hoefler Text
# Noto Sans Phoenician
# Courier New
# .SF NS Display Condensed
# .SF NS Text Condensed
# STIXSizeFourSym
# Arial
# Kokonor
# Noto Sans Limbu
# Arial Black
# YuKyokasho Yoko
# Bodoni 72 Smallcaps
# STIXNonUnicode
# Iowan Old Style
# Hannotate SC
# Noto Sans Kaithi
# DIN Alternate
# .SF Compact Display
# Arial
# Diwan Thuluth
# Noto Sans Buhid
# STIXGeneral
# .SF Compact Rounded
# DIN Condensed
# Times New Roman
# Ayuthaya
# .SF Compact Text
# New Peninim MT
# Devanagari MT
# Tahoma
# Hiragino Sans
# Tiro Hindi
# Noto Sans Yi
# Noto Sans Tai Viet
# GungSeo
# Noto Sans Lisu
# Zapfino
# Skia
# Hiragino Sans
# Mukta Vaani
# Gurmukhi MT
# Chalkboard
# Times New Roman
# Nanum Gothic
# Mukta
# Arial Narrow
# Baskerville
# Shree Devanagari 714
# Noto Sans Tagalog
# .New York
# Mukta Mahee
# Verdana
# Baloo Da
# Noto Sans Old Persian
# Verdana
# Noto Sans Rejang
# Noto Sans Lycian
# Lao MN
# Noto Sans Oriya
# System Font
# .SF NS Text Condensed
# Kaiti SC
# Arial Hebrew
# Nanum Myeongjo
# Noto Sans Shavian
# Apple Braille
# HanziPen SC
# .SF NS Mono
# .SF NS Text Condensed
# Farisi
# .SF NS Display Condensed
# Noto Sans Kannada
# Cambay Devanagari
# Corsiva Hebrew
# Kefa
# Myanmar MN
# Wawati SC
# STIXIntegralsUp
# Apple LiSung
# Noto Sans Samaritan
# Noto Sans Javanese
# Noto Serif Balinese
# Noto Sans Tifinagh
# Menlo
# Bradley Hand
# KufiStandardGK
# Hiragino Sans
# Bangla MN
# Jaini Purva
# PT Mono
# STHeiti
# YuMincho
# Noto Sans Meetei Mayek
# .SF NS Display Condensed
# Noto Sans Ol Chiki
# Tamil Sangam MN
# Gotu
# Arial Rounded MT Bold
# Snell Roundhand
# Noteworthy
# Bodoni 72 Oldstyle
# Microsoft Sans Serif
# Apple Braille
# Cochin
# STIXGeneral
# Noto Sans Tagbanwa
# Oriya MN
# Arial
# Brush Script MT
# Noto Sans Batak
# Noto Serif Kannada
# Trattatello
# Baloo
# Noto Sans Runic
# STIXGeneral
# Futura
# Georgia
# STIXSizeFiveSym
# Hiragino Sans
# Kohinoor Gujarati
# Baloo Bhaina
# PT Serif
# Mishafi
# Copperplate
# STIXIntegralsUpD
# PCMyungjo
# Malayalam Sangam MN
# Tiro Marathi
# Comic Sans MS
# Kohinoor Devanagari
# LiHei Pro
# Noto Sans Inscriptional Parthian
# Baloo Chettan
# Courier New
# Kohinoor Bangla
# Baoli SC
# Arial Unicode MS
# Big Caslon
# Avenir Next Condensed
# DecoType Naskh
# .SF NS Text Condensed
# Heiti TC
# Tahoma
# STIXVariants
# Noto Sans Buginese
# YuGothic
# Lantinghei SC
# Noto Sans Linear B
# Impact
# Avenir Next
# .Keyboard
# Noto Sans Hanunoo
# Oriya Sangam MN
# Weibei TC
# Noto Sans Syloti Nagri
# Noto Sans NKo
# Avenir
# Times New Roman
# Webdings
# PSL Ornanong Pro
# Osaka
# Tsukushi A Round Gothic
# STIXSizeTwoSym
# Gill Sans
# .SF NS Display Condensed
# Noto Sans Bamum
# .Aqua Kana
# Tiro Bangla
# Krungthep
# Hiragino Sans
# Savoye LET
# Noto Sans Coptic
# Toppan Bunkyu Gothic
# .SF NS Display Condensed
# Euphemia UCAS
# Jaini
# Noto Sans Sundanese
# Toppan Bunkyu Mincho
# Noto Sans Inscriptional Pahlavi
# Trebuchet MS
# Apple Braille
# Gujarati MT
# Wingdings
# Klee
# Arial Narrow
# PingFang HK
# Baloo Thambi
# Kannada MN
# Noto Sans Kharoshthi
# Wingdings 2
# Waseem
# Noto Sans Tai Le
# Marion
# Superclarendon
# Hiragino Sans CNS
# Noto Sans Old Turkic
# Noto Sans Vai
# .SF NS Mono
# STIXIntegralsUpSm
# LingWai TC
# Noto Sans Avestan
# Verdana
# Myanmar Sangam MN
# Baloo Paaji
# Hoefler Text
# American Typewriter
# Optima
# Palatino
# Verdana
# Chalkduster
# STIXSizeOneSym
# Tiro Sanskrit
# Nadeem
# Lucida Grande
# Noto Sans PhagsPa
# Tiro Kannada
# Trebuchet MS
# Sinhala Sangam MN
# SignPainter
# Apple Braille
# STIXNonUnicode
# STIXGeneral
# Hiragino Sans
# Chalkboard SE
# Seravek
# PT Sans
# Comic Sans MS
# Arial Unicode MS
# Beirut
# Didot
# Khmer MN
# Wingdings 3

# %% [markdown]
# # Exercises
#
# 1. **What principles for the visual display of quantitative information do our graphs violate?**
#
#
# 2. **Revise the chart** to better display the data, and save your code.
#
#
# 3. Using your revised graphs as a reference, **answer the following**. You are reading an older publication that found a two-fold difference in species richness between two environments, A and B, with B having about double the observed species diversity of A. However, there is a difference in average sequencing depth between the two: A has on average only 50 sequences per sample, while B  has about 1000. From this information, what can you conclude about the species richness of the real biological communities in environment A and B?
#
#
# 4. Aside from the formatting details, **do you think there are aspects of the simulation or overall graphing approach that would better communicate how sequencing depth (the number of DNA sequences collected per sample)
# affects perceived microbiome diversity?**
#
# 5. Try implementing one of your ideas from Exercise 4, and compare your rewritten version to the revised chart in step 2. Did it improve matters? Were there tradeoffs in what you were showing?
